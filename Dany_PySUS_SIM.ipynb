# %% [markdown]
# # SIM (Sistema de Informações sobre Mortalidade)
#
# https://pysus.readthedocs.io/en/latest/databases/SIM.html

# %% [markdown]
# ----------------------------------------------------

# %% [markdown]
# # Instalando as bibliotecas:

# %%
# !pip install -U git+https://github.com/AlertaDengue/PySUS.git    # instala a versão mais recente
# Out:
# ...
#   Cloning https://github.com/AlertaDengue/PySUS.git to /tmp/pip-req-build-clknoacd
#   Running command git clone --filter=blob:none --quiet https://github.com/AlertaDengue/PySUS.git /tmp/pip-req-build-clknoacd
#   Resolved https://github.com/AlertaDengue/PySUS.git to commit 54f7800db4da5171d55e3446d638d64beeb8b149
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 3.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 4.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 kB 3.8 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 3.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# https://pysus.readthedocs.io/en/latest/databases/SIM.html

# %%
# !pip install pysus
# Out:
# ...
# WARNING: elasticsearch 7.16.2 does not provide the extra 'preprocessing'
# ...

# %%
from pysus import SIM

# %%
import pandas as pd
from pandas import DataFrame
from pandas import concat

# %% [markdown]
# ------------------------

# %% [markdown]
# # SIM FTP Database
#
# # Sistema de Informação sobre Mortalidade

# %%
sim = SIM().load() # Loads the files from DATASUS

# %%
sim.metadata
# Out:
# {'long_name': 'Sistema de Informação sobre Mortalidade',
#  'source': 'http://sim.saude.gov.br',
#  'description': ''}

# %%
sim.groups
# Out:
# {'CID10': 'DO', 'CID9': 'DOR'}

# %%
sim.paths
# Out:
# (/dissemin/publicos/SIM/CID10/DORES, /dissemin/publicos/SIM/CID9/DORES)

# %% [markdown]
# Para mais informações sobre CID9 e CID10:
#
# http://tabnet.saude.es.gov.br/cgi/tabnet/sim/sim96/obtdescr.htm

# %% [markdown]
# ----------------------------------------------------

# %% [markdown]
# # Pegando arquivos específicos:

# %% [markdown]
# Dados até 1995 só podem ser recuperados pela CID-9.
#
# Dados de 1996 em diante só podem ser recuperados pela CID-10.

# %%
sim.get_files("CID10", uf=["SP", "RJ"], year=[2019, 2020, 2021])
# Out:
# [DORJ2019.dbc,
#  DORJ2020.dbc,
#  DORJ2021.dbc,
#  DOSP2019.dbc,
#  DOSP2020.dbc,
#  DOSP2021.dbc]

# %%
sim.get_files("CID10", uf="GO", year=2023)
# Out:
# []

# %%
sim.get_files("CID10", uf="GO", year=2022)
# Out:
# [DOGO2022.dbc]

# %%
arquivos = sim.get_files(["CID9", "CID10"], uf=["SP"], year=[1995, 2020])
sp_cid9, sp_cid10 = arquivos
sim.describe(sp_cid9)
# Out:
# {'name': 'DORSP95.DBC',
#  'uf': 'São Paulo',
#  'year': 1995,
#  'group': 'CID9',
#  'size': '8.2 MB',
#  'last_update': '2020-01-31 02:48PM'}

# %%
sim.describe(sp_cid10)
# Out:
# {'name': 'DOSP2020.dbc',
#  'uf': 'São Paulo',
#  'year': 2020,
#  'group': 'CID10',
#  'size': '28.7 MB',
#  'last_update': '2022-03-31 04:19PM'}

# %%
arquivos = sim.get_files(["CID10"], uf=["GO"], year=[2022])

# %%
arquivos
# Out:
# [DOGO2022.dbc]

# %%
sim.describe(arquivos[0])
# Out:
# {'name': 'DOGO2022.dbc',
#  'uf': 'Goiás',
#  'year': 2022,
#  'group': 'CID10',
#  'size': '4.4 MB',
#  'last_update': '2023-12-21 04:19PM'}

# %% [markdown]
# ----------------------------------------------------

# %% [markdown]
# # Downloading files

# %%
parquet = sim.download(arquivos)
# Out:
# DOGO2022.parquet: 100%|██████████| 116k/116k [00:08<00:00, 13.9kB/s]

# %%
parquet
# Out:
# /root/pysus/DOGO2022.parquet

# %% [markdown]
# ----------------------------------------------------

# %% [markdown]
# # Reading files

# %% [markdown]
# PySUS uses Parquets as output, use the method to_dataframe() to read the file as pandas DataFrame

# %%
parquet.to_dataframe()
# Out:
#       ORIGEM TIPOBITO   DTOBITO HORAOBITO NATURAL CODMUNNATU    DTNASC IDADE  \
# 0          1        2  02112022     0350      822    220170   20101940   482
# 1          1        2  30112022     0415      831    311370   09041939   483
# 2          1        2  23102022     1340      852    520870   15071972   450
# 3          1        2  02112022     1421      835    350780   12101932   490
# 4          1        2  30102022     1735      852    520870   18061962   460
# ...      ...      ...       ...       ...     ...        ...       ...   ...
# 47265      1        2  27112022     0002      822    220360   15061937   485
# 47266      1        2  20102022     2100      852    521740   28011950   472
# 47267      1        2  21102022     1217      852    521020   02031952   470
# 47268      1        2  01112022     2030      852    520400   12061945   477
# 47269      1        2  23102022     0640      852    520490   07051932   490
#
# ...

# %% [markdown]
# ----------------------------------------------------
# # Fazendo download para o computador

# %% [markdown]
# Primeiro arquivo da pasta DOGO2022.parquet:

# %%
df1 = pd.read_parquet('/root/pysus/DOGO2022.parquet/674908bbbb854890842293409d69ff1b-0.parquet')
# Endereço de onde o arquivo é salvo na raiz do google colab

# %%
df1
# Out:
#       ORIGEM TIPOBITO   DTOBITO HORAOBITO NATURAL CODMUNNATU    DTNASC IDADE  \
# 0          1        2  02112022     0350      822    220170   20101940   482
# 1          1        2  30112022     0415      831    311370   09041939   483
# 2          1        2  23102022     1340      852    520870   15071972   450
# 3          1        2  02112022     1421      835    350780   12101932   490
# 4          1        2  30102022     1735      852    520870   18061962   460
# ...      ...      ...       ...       ...     ...        ...       ...   ...
# 17265      1        2  11102022     0120      852    521850   30101945   476
# 17266      1        2  04102022     1645      829    290710   16091976   446
# 17267      1        2  11102022     0340      829    292720   10061926   496
# 17268      1        2  09102022     2309      852    521150   05081950   472
# 17269      1        2  03102022     2300      835    352640   26071981   441
#
# ...

# %%
# Salvando o arquivo localmente no ambiente do Colab
# o arquivo é salvo no sistema de arquivos temporário do Colab, dentro do diretório padrão /content.
df1.to_csv('SIM1.csv', index=True)

# %%
# Fazendo download para o computador
from google.colab import files
files.download('/content/SIM1.csv')

# %% [markdown]
# ----------------------------------------------------

# %% [markdown]
# Segundo arquivo da pasta DOGO2022.parquet:

# %%
df2 = pd.read_parquet('/root/pysus/DOGO2022.parquet/eca3c827d1344672a689558e0a3e7eed-0.parquet')

# %%
df2
# Out:
#       ORIGEM TIPOBITO   DTOBITO HORAOBITO NATURAL CODMUNNATU    DTNASC IDADE  \
# 0          1        2  27012022     2330      822    220770   27061962   459
# 1          1        2  01012022     2325      831    314330   08111948   473
# 2          1        2  24022022     0651      853    530010   27111984   437
# 3          1        2  16022022     1053      829    290390   02111968   453
# 4          1        2  24022022     1023      835    355030   13102015   406
# ...      ...      ...       ...       ...     ...        ...       ...   ...
# 29995      1        2  27112022     0002      822    220360   15061937   485
# 29996      1        2  20102022     2100      852    521740   28011950   472
# 29997      1        2  21102022     1217      852    521020   02031952   470
# 29998      1        2  01112022     2030      852    520400   12061945   477
# 29999      1        2  23102022     0640      852    520490   07051932   490
#
# ...

# %%
# Salvando o arquivo localmente no ambiente do Colab
# o arquivo é salvo no sistema de arquivos temporário do Colab, dentro do diretório padrão /content.
df2.to_csv('SIM2.csv', index=True)

# %%
# Fazendo download para o computador
from google.colab import files
files.download('/content/SIM2.csv')

# %% [markdown]
# ---------------------------
# --------------------------
# CÓDIGO AGRUPADO:

# %%
# LIMPA ARQUIVOS DE EXECUÇÕES ANTERIORES
import shutil
import os

# Caminho da pasta
caminho_pasta = '/root/pysus'

# Verificar se a pasta existe antes de apagar
if os.path.exists(caminho_pasta):
    shutil.rmtree(caminho_pasta)  # Remove a pasta inteira
    print(f"A pasta {caminho_pasta} foi apagada.")
else:
    print("A pasta já está apagada. Siga em diante.")
# Out:
# A pasta /root/pysus foi apagada.

# %%
# Instalando as bibliotecas:
# !pip install -U git+https://github.com/AlertaDengue/PySUS.git    # instala a versão mais recente
# !pip install pysus

from pysus import SIM
import pandas as pd
from pandas import DataFrame
from pandas import concat


# SIM FTP Database
sim = SIM().load() # Loads the files from DATASUS
sim.metadata
sim.paths
# Out:
# ...
#   Cloning https://github.com/AlertaDengue/PySUS.git to /tmp/pip-req-build-jnwjb9d6
#   Running command git clone --filter=blob:none --quiet https://github.com/AlertaDengue/PySUS.git /tmp/pip-req-build-jnwjb9d6
#   Resolved https://github.com/AlertaDengue/PySUS.git to commit 54f7800db4da5171d55e3446d638d64beeb8b149
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 4.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 2.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 kB 4.1 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 2.9 MB/s eta 0:00:00
# ...

# %%
sim.groups
# Out:
# {'CID10': 'DO', 'CID9': 'DOR'}

# %% [markdown]
# Dados até 1995 só podem ser recuperados pela CID-9.
#
# Dados de 1996 em diante só podem ser recuperados pela CID-10.

# %% [markdown]
# -----------------------

# %% [markdown]
# EDITE CONFORME SUA NECESIDADE:

# %%
# Sistema = ["SIM"]

# %%
my_group = ["CID10"]      # Para dois: ["CID9","CID10"], etc...
my_state = ["GO"]       # Para dois: ["GO","SP"], etc...
my_year = [2022]        # Para dois: [2021, 2022], etc...

# %%
# Pegando arquivos específicos:
arquivos = sim.get_files(my_group, uf=my_state, year=my_year)
## arquivos = sim.get_files("CID10", uf=["SP", "RJ"], year=[2019, 2020, 2021])
arquivos
# Out:
# [DOGO2022.dbc]

# %%
for d in range(len(arquivos)):
  arquivos[d]
  sim.describe(arquivos[d])


  # Downloading files
  parquet_list = sim.download(arquivos[d])    # localizado no google colab, na pasta root/root/pysus/.

  if type(parquet_list)!=list:        # Se parquet_list não for uma lista, transforma em lista.
    parquet_list = [parquet_list]     # transforma em lista para poder utilizar o "for" abaixo, padrão para todos os códigos gerados.

# -----------------------------------------

  for j in range(len(parquet_list)):
# for parquet in parquet_list:
  # Reading files
    parquet_list[j].to_dataframe()

  #------------
  # Fazendo download para o computador
  import os

  # Listar arquivos no diretório atual
  lista_arquivos = os.listdir(f'{parquet_list[j]}')
  #print(f"Arquivos em {parquet_list}:", lista_arquivos)

  from google.colab import files

# O 'for' foi dividido em 3 devido a falhas ao baixar os arquivos com muitos dados. Alguns não estavam sendo baixados.
# Se a falha persistir ao baixar os arquivos para o computador, baixe-os diretamente em: '/root/pysus/'
  for i in range(len(lista_arquivos)):
    df = pd.read_parquet(f'{parquet_list[j]}/{lista_arquivos[i]}')
    df.to_csv(f'{parquet_list[j]}/SIH_{d}_{j}_{i}.csv', index=True)
    # files.download(f'{parquet_list[j]}/SIH_{d}_{j}_{i}.csv') # Fazendo download para o computador
    # files.download(f'{parquet_list[j]}/{lista_arquivos[i]}') # Fazendo download para o computador

  for i in range(len(lista_arquivos)):
    # df = pd.read_parquet(f'{parquet_list[j]}/{lista_arquivos[i]}')
    # df.to_csv(f'{parquet_list[j]}/SIH_{d}_{j}_{i}.csv', index=True)
    files.download(f'{parquet_list[j]}/SIH_{d}_{j}_{i}.csv') # Fazendo download para o computador
    # files.download(f'{parquet_list[j]}/{lista_arquivos[i]}') # Fazendo download para o computador

  for i in range(len(lista_arquivos)):
    # df = pd.read_parquet(f'{parquet_list[j]}/{lista_arquivos[i]}')
    # df.to_csv(f'{parquet_list[j]}/SIH_{d}_{j}_{i}.csv', index=True)
    # files.download(f'{parquet_list[j]}/SIH_{d}_{j}_{i}.csv') # Fazendo download para o computador
    files.download(f'{parquet_list[j]}/{lista_arquivos[i]}') # Fazendo download para o computador
# Out:
# DOGO2022.parquet: 100%|██████████| 116k/116k [00:06<00:00, 16.7kB/s]

# %% [markdown]
# OS ARQUIVOS TAMBÉM PODEM SER ACESSADOS EM '/root/pysus/', PASTA RAIZ DO GOOGLE COLAB.
